# %%
import pandas as pd

# %%
filename = 'data/past_matches.csv'
df = pd.read_csv(filename)

# %%
df
# Out:
#       Unnamed: 0  home_score_home  home_score_away  home_half_score_home  \
# 0              0         1.000000         1.500000              0.000000
# 1              0         1.666667         1.000000              0.000000
# 2              0         1.000000         0.000000              0.000000
# 3              0         2.000000         1.000000              0.000000
# 4              0         1.000000         2.000000              0.000000
# 5              0         2.000000         2.000000              0.000000
# 6              0         2.000000         1.333333              0.000000
# 7              0         1.666667         0.666667              0.000000
# 8              0         1.500000         0.000000              0.000000
# 9              0         2.666667         2.000000              0.000000
# 10             0         1.750000         0.750000              0.000000
# 11             0         2.000000         1.000000              0.000000
# ...
